# %% [markdown]
# # Documentation and theory for `BANTS`
#
# ---
#
# ## Motivating background
#
# \textcolor{red}{1. USE ABSTRACT MARKET PHENOMENA ONLY 2. Apply the nonperturbative renormalisation group like the information bottleneck to look at scaling of optimal effective descriptions 3. Compute the Bayesian evidence for model selection of different possible market structures --- this could even lead to dynamical evidence-weighted ensembles 4. Apply all of the theory developed in this paper in \href{https://github.com/umbralcalc/bants}{\texttt{BANTS}}.}
#
# Consider the hierarchical model
#
# $$
# \begin{equation}
# {\cal P}(\boldsymbol{\theta}\vert d) = \frac{{\cal L}(d\vert \boldsymbol{\theta})\pi (\boldsymbol{\theta})}{{\cal E}(d)} = \frac{{\cal L}(d\vert \boldsymbol{\theta})}{{\cal E}(d)}\int {\rm d}\boldsymbol{\eta}\,p(\boldsymbol{\theta}\vert \boldsymbol{\eta})\,p(\boldsymbol{\eta}) \,.
# \end{equation}
# $$

# %% [markdown]
# - Statistical inference of agent-based models of financial markets: Refs.~\cite{alfarano2005estimation, heard2015agent, chen2017new, grazzini2017bayesian, bertschinger2021bayesian}. In particular, have a look at these slides \href{https://www.samsi.info/wp-content/uploads/2016/03/Heard_may7_2014.pdf}{here}.
# - Agent-based simulation models of a financial markets: Refs.~\cite{raberto2001agent, boer2008agent, benhammada2010semi, rekik2014agent, kim2014group, chen2015agent, wang2018agent}. In particular, use the citations of Ref.~\cite{wang2018agent} to get more references.
# - Agent-based simulation of a housing markets: Refs.~\cite{vinogradov2020agent}.

# %% [markdown]
# @article{raberto2001agent,
#   title={Agent-based simulation of a financial market},
#   author={Raberto, Marco and Cincotti, Silvano and Focardi, Sergio M and Marchesi, Michele},
#   journal={Physica A: Statistical Mechanics and its Applications},
#   volume={299},
#   number={1-2},
#   pages={319--327},
#   year={2001},
#   publisher={Elsevier}
# }
#
# @article{vinogradov2020agent,
#   title={An agent-based modelling approach to housing market regulations and Airbnb-induced tourism},
#   author={Vinogradov, Evgueni and Leick, Birgit and Kivedal, Bj{\o}rnar Karlsen},
#   journal={Tourism Management},
#   volume={77},
#   pages={104004},
#   year={2020},
#   publisher={Elsevier}
# }
#
# @article{heard2015agent,
#   title={Agent-based models and microsimulation},
#   author={Heard, Daniel and Dent, Gelonia and Schifeling, Tracy and Banks, David},
#   journal={Annual Review of Statistics and Its Application},
#   volume={2},
#   pages={259--272},
#   year={2015},
#   publisher={Annual Reviews}
# }
#
# @article{bertschinger2021bayesian,
#   title={Bayesian estimation and likelihood-based comparison of agent-based volatility models},
#   author={Bertschinger, Nils and Mozzhorin, Iurii},
#   journal={Journal of Economic Interaction and Coordination},
#   volume={16},
#   number={1},
#   pages={173--210},
#   year={2021},
#   publisher={Springer}
# }
#
# @article{grazzini2017bayesian,
#   title={Bayesian estimation of agent-based models},
#   author={Grazzini, Jakob and Richiardi, Matteo G and Tsionas, Mike},
#   journal={Journal of Economic Dynamics and Control},
#   volume={77},
#   pages={26--47},
#   year={2017},
#   publisher={Elsevier}
# }
#
# @inproceedings{wang2018agent,
#   title={Agent-based models in financial market studies},
#   author={Wang, L and Ahn, Kwangwon and Kim, C and Ha, C},
#   booktitle={Journal of Physics: Conference Series},
#   volume={1039},
#   number={1},
#   pages={012022},
#   year={2018},
#   organization={IOP Publishing}
# }
#
# @article{chen2017new,
#   title={New approaches in agent-based modeling of complex financial systems},
#   author={Chen, Ting-Ting and Zheng, Bo and Li, Yan and Jiang, Xiong-Fei},
#   journal={Frontiers of Physics},
#   volume={12},
#   number={6},
#   pages={1--12},
#   year={2017},
#   publisher={Springer}
# }
#
# @article{alfarano2005estimation,
#   title={Estimation of agent-based models: the case of an asymmetric herding model},
#   author={Alfarano, Simone and Lux, Thomas and Wagner, Friedrich},
#   journal={Computational Economics},
#   volume={26},
#   number={1},
#   pages={19--49},
#   year={2005},
#   publisher={Springer}
# }
#
# @article{rekik2014agent,
#   title={Agent-based modeling and investors’ behavior explanation of asset price dynamics on artificial financial markets},
#   author={Rekik, Yosra Mefteh and Hachicha, Wafik and Boujelbene, Younes},
#   journal={Procedia Economics and Finance},
#   volume={13},
#   pages={30--46},
#   year={2014},
#   publisher={Elsevier}
# }
#
# @article{kim2014group,
#   title={Group-wise herding behavior in financial markets: an agent-based modeling approach},
#   author={Kim, Minsung and Kim, Minki},
#   journal={PloS one},
#   volume={9},
#   number={4},
#   pages={e93661},
#   year={2014},
#   publisher={Public Library of Science}
# }
#
# @article{chen2015agent,
#   title={Agent-based model with multi-level herding for complex financial systems},
#   author={Chen, Jun-Jie and Tan, Lei and Zheng, Bo},
#   journal={Scientific reports},
#   volume={5},
#   number={1},
#   pages={1--7},
#   year={2015},
#   publisher={Nature Publishing Group}
# }
#
# @article{benhammada2010semi,
#   title={A semi-formal specification for a generic model of artificial stock markets},
#   author={Benhammada, Sadek and Chikhi, Salim},
#   journal={Procedia Computer Science},
#   volume={1},
#   number={1},
#   pages={1465--1474},
#   year={2010},
#   publisher={Elsevier}
# }
#
# @book{boer2008agent,
#   title={Agent-based simulation of financial markets: a modular, continuous-time approach},
#   author={Boer-Sorban, Katalin},
#   number={EPS-2008-119-LIS},
#   year={2008}
# }
